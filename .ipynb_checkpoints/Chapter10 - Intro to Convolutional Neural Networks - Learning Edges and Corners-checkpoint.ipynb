# %% [markdown]
# # Upgrading our MNIST Network

# %%
import numpy as np, sys
np.random.seed(1)

from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000,28*28) / 255,
                  y_train[0:1000])


one_hot_labels = np.zeros((len(labels),10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

alpha, iterations = (2, 300)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * 
               (input_cols - kernel_cols)) * num_kernels

# weights_0_1 = 0.02*np.random.random((pixels_per_image,hidden_size))-0.01
kernels = 0.02*np.random.random((kernel_rows*kernel_cols,
                                 num_kernels))-0.01  # 9,16

weights_1_2 = 0.2*np.random.random((hidden_size,
                                    num_labels)) - 0.1 # 10000,10


def get_image_section(layer,row_from, row_to, col_from, col_to):
    section = layer[:,row_from:row_to,col_from:col_to]
    return section.reshape(-1,1,row_to-row_from, col_to-col_from) # 128,1,3,3

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end=((i * batch_size),((i+1)*batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28) # 128,28,28
        
        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape # 128,625,3,3 ((28-3)*(28-3)=625)
        flattened_input = expanded_input.reshape(es[0]*es[1],-1) # 80000,9

        kernel_output = flattened_input.dot(kernels) #80000,9 dot 9,16 = 80000,16
        layer_1 = tanh(kernel_output.reshape(es[0],-1)) # 128,10000
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2)) # 128,10

        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == 
                               np.argmax(labelset))
            correct_cnt += _inc

        layer_2_delta = (labels[batch_start:batch_end]-layer_2)\
                        / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * \
                        tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
    
    test_correct_cnt = 0

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
#         layer_1 = tanh(np.dot(layer_0,weights_0_1))
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        layer_2 = np.dot(layer_1,weights_1_2)

        test_correct_cnt += int(np.argmax(layer_2) == 
                                np.argmax(test_labels[i:i+1]))
    if(j % 1 == 0):
        sys.stdout.write("\n"+ \
         "I:" + str(j) + \
         " Test-Acc:"+str(test_correct_cnt/float(len(test_images)))+\
         " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
# I:0 Test-Acc:0.093 Train-Acc:0.078
# I:1 Test-Acc:0.0767 Train-Acc:0.068
# I:2 Test-Acc:0.078 Train-Acc:0.064
# I:3 Test-Acc:0.0808 Train-Acc:0.07
# I:4 Test-Acc:0.0886 Train-Acc:0.066
# I:5 Test-Acc:0.1059 Train-Acc:0.073
# I:6 Test-Acc:0.1272 Train-Acc:0.1
# I:7 Test-Acc:0.1577 Train-Acc:0.12
# I:8 Test-Acc:0.2287 Train-Acc:0.123
# I:9 Test-Acc:0.3095 Train-Acc:0.157
# I:10 Test-Acc:0.3652 Train-Acc:0.192
# I:11 Test-Acc:0.3909 Train-Acc:0.208
# I:12 Test-Acc:0.3852 Train-Acc:0.228
# I:13 Test-Acc:0.3357 Train-Acc:0.215
# I:14 Test-Acc:0.1942 Train-Acc:0.187
# I:15 Test-Acc:0.0742 Train-Acc:0.107
# I:16 Test-Acc:0.0336 Train-Acc:0.055
# I:17 Test-Acc:0.0161 Train-Acc:0.041
# I:18 Test-Acc:0.0121 Train-Acc:0.025
# I:19 Test-Acc:0.0146 Train-Acc:0.025
# I:20 Test-Acc:0.0259 Train-Acc:0.049
# I:21 Test-Acc:0.0622 Train-Acc:0.07
# I:22 Test-Acc:0.1282 Train-Acc:0.108
# I:23 Test-Acc:0.2387 Train-Acc:0.139
# I:24 Test-Acc:0.3398 Train-Acc:0.177
# I:25 Test-Acc:0.4291 Train-Acc:0.21
# I:26 Test-Acc:0.4941 Train-Acc:0.27
# I:27 Test-Acc:0.544 Train-Acc:0.328
# I:28 Test-Acc:0.5777 Train-Acc:0.332
# I:29 Test-Acc:0.6022 Train-Acc:0.375
# I:30 Test-Acc:0.6204 Train-Acc:0.397
# I:31 Test-Acc:0.6275 Train-Acc:0.453
# I:32 Test-Acc:0.6349 Train-Acc:0.423
# I:33 Test-Acc:0.6341 Train-Acc:0.444
# I:34 Test-Acc:0.6208 Train-Acc:0.437
# I:35 Test-Acc:0.5897 Train-Acc:0.405
# I:36 Test-Acc:0.5421 Train-Acc:0.36
# I:37 Test-Acc:0.4328 Train-Acc:0.318
# I:38 Test-Acc:0.2323 Train-Acc:0.229
# I:39 Test-Acc:0.0394 Train-Acc:0.114
# I:40 Test-Acc:0.0124 Train-Acc:0.042
# I:41 Test-Acc:0.0112 Train-Acc:0.03
# I:42 Test-Acc:0.015 Train-Acc:0.029
# I:43 Test-Acc:0.0256 Train-Acc:0.036
# I:44 Test-Acc:0.0593 Train-Acc:0.048
# I:45 Test-Acc:0.1941 Train-Acc:0.077
# I:46 Test-Acc:0.3584 Train-Acc:0.158
# I:47 Test-Acc:0.5126 Train-Acc:0.214
# I:48 Test-Acc:0.6232 Train-Acc:0.284
# I:49 Test-Acc:0.6863 Train-Acc:0.351
# I:50 Test-Acc:0.7174 Train-Acc:0.388
# I:51 Test-Acc:0.7329 Train-Acc:0.448
# I:52 Test-Acc:0.7501 Train-Acc:0.445
# I:53 Test-Acc:0.7627 Train-Acc:0.496
# I:54 Test-Acc:0.77 Train-Acc:0.512
# I:55 Test-Acc:0.7739 Train-Acc:0.522
# I:56 Test-Acc:0.7787 Train-Acc:0.542
# I:57 Test-Acc:0.7836 Train-Acc:0.547
# I:58 Test-Acc:0.7858 Train-Acc:0.562
# I:59 Test-Acc:0.7927 Train-Acc:0.585
# I:60 Test-Acc:0.7945 Train-Acc:0.589
# I:61 Test-Acc:0.8005 Train-Acc:0.618
# I:62 Test-Acc:0.7999 Train-Acc:0.629
# I:63 Test-Acc:0.8057 Train-Acc:0.632
# I:64 Test-Acc:0.8034 Train-Acc:0.635
# I:65 Test-Acc:0.8073 Train-Acc:0.637
# I:66 Test-Acc:0.8115 Train-Acc:0.631
# I:67 Test-Acc:0.8134 Train-Acc:0.639
# I:68 Test-Acc:0.8162 Train-Acc:0.659
# I:69 Test-Acc:0.8173 Train-Acc:0.636
# I:70 Test-Acc:0.8207 Train-Acc:0.666
# I:71 Test-Acc:0.8216 Train-Acc:0.693
# I:72 Test-Acc:0.826 Train-Acc:0.682
# I:73 Test-Acc:0.8294 Train-Acc:0.687
# I:74 Test-Acc:0.8265 Train-Acc:0.69
# I:75 Test-Acc:0.8292 Train-Acc:0.68
# I:76 Test-Acc:0.8309 Train-Acc:0.697
# I:77 Test-Acc:0.8348 Train-Acc:0.709
# I:78 Test-Acc:0.8348 Train-Acc:0.696
# I:79 Test-Acc:0.8372 Train-Acc:0.689
# I:80 Test-Acc:0.8409 Train-Acc:0.717
# I:81 Test-Acc:0.8368 Train-Acc:0.705
# I:82 Test-Acc:0.8406 Train-Acc:0.715
# I:83 Test-Acc:0.842 Train-Acc:0.715
# I:84 Test-Acc:0.844 Train-Acc:0.717
# I:85 Test-Acc:0.8439 Train-Acc:0.713
# I:86 Test-Acc:0.8454 Train-Acc:0.728
# I:87 Test-Acc:0.8477 Train-Acc:0.708
# I:88 Test-Acc:0.8481 Train-Acc:0.743
# I:89 Test-Acc:0.8512 Train-Acc:0.727
# I:90 Test-Acc:0.8507 Train-Acc:0.723
# I:91 Test-Acc:0.847 Train-Acc:0.727
# I:92 Test-Acc:0.8507 Train-Acc:0.732
# I:93 Test-Acc:0.8519 Train-Acc:0.739
# I:94 Test-Acc:0.8547 Train-Acc:0.737
# I:95 Test-Acc:0.8558 Train-Acc:0.73
# I:96 Test-Acc:0.8577 Train-Acc:0.74
# I:97 Test-Acc:0.8549 Train-Acc:0.734
# I:98 Test-Acc:0.8599 Train-Acc:0.744
# I:99 Test-Acc:0.8572 Train-Acc:0.741
# I:100 Test-Acc:0.862 Train-Acc:0.725
# I:101 Test-Acc:0.8622 Train-Acc:0.754
# I:102 Test-Acc:0.8616 Train-Acc:0.751
# I:103 Test-Acc:0.8616 Train-Acc:0.756
# I:104 Test-Acc:0.8598 Train-Acc:0.739
# I:105 Test-Acc:0.862 Train-Acc:0.75
# I:106 Test-Acc:0.8619 Train-Acc:0.741
# I:107 Test-Acc:0.863 Train-Acc:0.74
# I:108 Test-Acc:0.8638 Train-Acc:0.748
# I:109 Test-Acc:0.8641 Train-Acc:0.761
# I:110 Test-Acc:0.8644 Train-Acc:0.758
# I:111 Test-Acc:0.8642 Train-Acc:0.741
# I:112 Test-Acc:0.8639 Train-Acc:0.768
# I:113 Test-Acc:0.8661 Train-Acc:0.757
# I:114 Test-Acc:0.8675 Train-Acc:0.749
# I:115 Test-Acc:0.8644 Train-Acc:0.762
# I:116 Test-Acc:0.8654 Train-Acc:0.742
# I:117 Test-Acc:0.8652 Train-Acc:0.752
# I:118 Test-Acc:0.8665 Train-Acc:0.761
# I:119 Test-Acc:0.8681 Train-Acc:0.766
# I:120 Test-Acc:0.8668 Train-Acc:0.748
# I:121 Test-Acc:0.8661 Train-Acc:0.759
# I:122 Test-Acc:0.8657 Train-Acc:0.768
# I:123 Test-Acc:0.8677 Train-Acc:0.753
# I:124 Test-Acc:0.8661 Train-Acc:0.763
# I:125 Test-Acc:0.8667 Train-Acc:0.765
# I:126 Test-Acc:0.8645 Train-Acc:0.761
# I:127 Test-Acc:0.8689 Train-Acc:0.772
# I:128 Test-Acc:0.8702 Train-Acc:0.77
# I:129 Test-Acc:0.8699 Train-Acc:0.773
# I:130 Test-Acc:0.8711 Train-Acc:0.757
# I:131 Test-Acc:0.8715 Train-Acc:0.754
# I:132 Test-Acc:0.8689 Train-Acc:0.779
# I:133 Test-Acc:0.8718 Train-Acc:0.753
# I:134 Test-Acc:0.8718 Train-Acc:0.775
# I:135 Test-Acc:0.871 Train-Acc:0.766
# I:136 Test-Acc:0.8724 Train-Acc:0.77
# I:137 Test-Acc:0.8721 Train-Acc:0.782
# I:138 Test-Acc:0.8706 Train-Acc:0.783
# I:139 Test-Acc:0.8724 Train-Acc:0.771
# I:140 Test-Acc:0.8706 Train-Acc:0.773
# I:141 Test-Acc:0.8729 Train-Acc:0.766
# I:142 Test-Acc:0.8708 Train-Acc:0.774
# I:143 Test-Acc:0.8703 Train-Acc:0.771
# I:144 Test-Acc:0.8712 Train-Acc:0.774
# I:145 Test-Acc:0.8732 Train-Acc:0.776
# I:146 Test-Acc:0.8707 Train-Acc:0.775
# I:147 Test-Acc:0.8716 Train-Acc:0.773
# I:148 Test-Acc:0.8752 Train-Acc:0.776
# I:149 Test-Acc:0.8745 Train-Acc:0.778
# I:150 Test-Acc:0.8751 Train-Acc:0.78
# I:151 Test-Acc:0.8739 Train-Acc:0.774
# I:152 Test-Acc:0.8744 Train-Acc:0.772
# I:153 Test-Acc:0.8748 Train-Acc:0.776
# I:154 Test-Acc:0.8772 Train-Acc:0.783
# I:155 Test-Acc:0.8758 Train-Acc:0.776
# I:156 Test-Acc:0.8713 Train-Acc:0.779
# I:157 Test-Acc:0.8743 Train-Acc:0.777
# I:158 Test-Acc:0.8754 Train-Acc:0.782
# I:159 Test-Acc:0.8755 Train-Acc:0.783
# I:160 Test-Acc:0.8726 Train-Acc:0.777
# I:161 Test-Acc:0.8735 Train-Acc:0.778
# I:162 Test-Acc:0.8737 Train-Acc:0.792
# I:163 Test-Acc:0.8745 Train-Acc:0.793
# I:164 Test-Acc:0.8788 Train-Acc:0.784
# I:165 Test-Acc:0.8794 Train-Acc:0.781
# I:166 Test-Acc:0.8774 Train-Acc:0.792
# I:167 Test-Acc:0.8787 Train-Acc:0.784
# I:168 Test-Acc:0.8757 Train-Acc:0.791
# I:169 Test-Acc:0.8759 Train-Acc:0.788
# I:170 Test-Acc:0.8757 Train-Acc:0.786
# I:171 Test-Acc:0.8774 Train-Acc:0.791
# I:172 Test-Acc:0.8793 Train-Acc:0.787
# I:173 Test-Acc:0.8787 Train-Acc:0.801
# I:174 Test-Acc:0.8762 Train-Acc:0.784
# I:175 Test-Acc:0.8771 Train-Acc:0.79
# I:176 Test-Acc:0.8771 Train-Acc:0.788
# I:177 Test-Acc:0.8795 Train-Acc:0.791
# I:178 Test-Acc:0.8754 Train-Acc:0.791
# I:179 Test-Acc:0.8765 Train-Acc:0.79
# I:180 Test-Acc:0.8743 Train-Acc:0.797
# I:181 Test-Acc:0.8783 Train-Acc:0.795
# I:182 Test-Acc:0.8767 Train-Acc:0.787
# I:183 Test-Acc:0.8777 Train-Acc:0.786
# I:184 Test-Acc:0.8787 Train-Acc:0.783
# I:185 Test-Acc:0.8783 Train-Acc:0.79
# I:186 Test-Acc:0.8762 Train-Acc:0.795
# I:187 Test-Acc:0.8782 Train-Acc:0.782
# I:188 Test-Acc:0.879 Train-Acc:0.802
# I:189 Test-Acc:0.8793 Train-Acc:0.789
# I:190 Test-Acc:0.8765 Train-Acc:0.787
# I:191 Test-Acc:0.876 Train-Acc:0.802
# I:192 Test-Acc:0.8783 Train-Acc:0.807
# I:193 Test-Acc:0.8781 Train-Acc:0.797
# I:194 Test-Acc:0.8748 Train-Acc:0.79
# I:195 Test-Acc:0.8778 Train-Acc:0.794
# I:196 Test-Acc:0.8754 Train-Acc:0.782
# I:197 Test-Acc:0.8761 Train-Acc:0.81
# I:198 Test-Acc:0.8773 Train-Acc:0.806
# I:199 Test-Acc:0.8759 Train-Acc:0.797
# I:200 Test-Acc:0.8782 Train-Acc:0.798
# I:201 Test-Acc:0.8796 Train-Acc:0.805
# I:202 Test-Acc:0.8779 Train-Acc:0.8
# I:203 Test-Acc:0.8747 Train-Acc:0.799
# I:204 Test-Acc:0.8789 Train-Acc:0.787
# I:205 Test-Acc:0.8783 Train-Acc:0.801
# I:206 Test-Acc:0.8769 Train-Acc:0.804
# I:207 Test-Acc:0.8773 Train-Acc:0.792
# I:208 Test-Acc:0.8771 Train-Acc:0.8
# I:209 Test-Acc:0.8793 Train-Acc:0.804
# I:210 Test-Acc:0.8796 Train-Acc:0.806
# I:211 Test-Acc:0.8793 Train-Acc:0.799
# I:212 Test-Acc:0.8786 Train-Acc:0.786
# I:213 Test-Acc:0.8773 Train-Acc:0.806
# I:214 Test-Acc:0.8778 Train-Acc:0.808
# I:215 Test-Acc:0.8796 Train-Acc:0.801
# I:216 Test-Acc:0.8799 Train-Acc:0.794
# I:217 Test-Acc:0.8787 Train-Acc:0.812
# I:218 Test-Acc:0.878 Train-Acc:0.807
# I:219 Test-Acc:0.8788 Train-Acc:0.796
# I:220 Test-Acc:0.8774 Train-Acc:0.81
# I:221 Test-Acc:0.8788 Train-Acc:0.795
# I:222 Test-Acc:0.8809 Train-Acc:0.811
# I:223 Test-Acc:0.879 Train-Acc:0.818
# I:224 Test-Acc:0.8783 Train-Acc:0.797
# I:225 Test-Acc:0.877 Train-Acc:0.807
# I:226 Test-Acc:0.8777 Train-Acc:0.797
# I:227 Test-Acc:0.8786 Train-Acc:0.809
# I:228 Test-Acc:0.8794 Train-Acc:0.801
# I:229 Test-Acc:0.8796 Train-Acc:0.807
# I:230 Test-Acc:0.8801 Train-Acc:0.809
# I:231 Test-Acc:0.8799 Train-Acc:0.791
# I:232 Test-Acc:0.8795 Train-Acc:0.807
# I:233 Test-Acc:0.8791 Train-Acc:0.811
# I:234 Test-Acc:0.8781 Train-Acc:0.808
# I:235 Test-Acc:0.879 Train-Acc:0.807
# I:236 Test-Acc:0.8789 Train-Acc:0.807
# I:237 Test-Acc:0.8785 Train-Acc:0.802
# I:238 Test-Acc:0.8781 Train-Acc:0.797
# I:239 Test-Acc:0.8786 Train-Acc:0.805
# I:240 Test-Acc:0.881 Train-Acc:0.812
# I:241 Test-Acc:0.8779 Train-Acc:0.798
# I:242 Test-Acc:0.8802 Train-Acc:0.808
# I:243 Test-Acc:0.8787 Train-Acc:0.812
# I:244 Test-Acc:0.8789 Train-Acc:0.819
# I:245 Test-Acc:0.8771 Train-Acc:0.817
# I:246 Test-Acc:0.8769 Train-Acc:0.795
# I:247 Test-Acc:0.8775 Train-Acc:0.814
# I:248 Test-Acc:0.8788 Train-Acc:0.81
# I:249 Test-Acc:0.8804 Train-Acc:0.816
# I:250 Test-Acc:0.8777 Train-Acc:0.817
# I:251 Test-Acc:0.8786 Train-Acc:0.813
# I:252 Test-Acc:0.8778 Train-Acc:0.809
# I:253 Test-Acc:0.8788 Train-Acc:0.812
# I:254 Test-Acc:0.8777 Train-Acc:0.81
# I:255 Test-Acc:0.8778 Train-Acc:0.804
# I:256 Test-Acc:0.8768 Train-Acc:0.801
# I:257 Test-Acc:0.8773 Train-Acc:0.81
# I:258 Test-Acc:0.8785 Train-Acc:0.806
# I:259 Test-Acc:0.8755 Train-Acc:0.811
# I:260 Test-Acc:0.8772 Train-Acc:0.809
# I:261 Test-Acc:0.8773 Train-Acc:0.804
# I:262 Test-Acc:0.877 Train-Acc:0.813
# I:263 Test-Acc:0.8793 Train-Acc:0.812
# I:264 Test-Acc:0.8781 Train-Acc:0.827
# I:265 Test-Acc:0.8781 Train-Acc:0.819
# I:266 Test-Acc:0.8788 Train-Acc:0.812
# I:267 Test-Acc:0.8777 Train-Acc:0.802
# I:268 Test-Acc:0.877 Train-Acc:0.804
# I:269 Test-Acc:0.8762 Train-Acc:0.819
# I:270 Test-Acc:0.8787 Train-Acc:0.817
# I:271 Test-Acc:0.8779 Train-Acc:0.834
# I:272 Test-Acc:0.8767 Train-Acc:0.82
# I:273 Test-Acc:0.8763 Train-Acc:0.821
# I:274 Test-Acc:0.877 Train-Acc:0.807
# I:275 Test-Acc:0.8768 Train-Acc:0.816
# I:276 Test-Acc:0.8782 Train-Acc:0.817
# I:277 Test-Acc:0.8768 Train-Acc:0.802
# I:278 Test-Acc:0.8769 Train-Acc:0.811
# I:279 Test-Acc:0.8763 Train-Acc:0.826
# I:280 Test-Acc:0.8775 Train-Acc:0.828
# I:281 Test-Acc:0.8783 Train-Acc:0.814
# I:282 Test-Acc:0.8756 Train-Acc:0.817
# I:283 Test-Acc:0.8777 Train-Acc:0.812
# I:284 Test-Acc:0.8776 Train-Acc:0.819
# I:285 Test-Acc:0.8775 Train-Acc:0.822
# I:286 Test-Acc:0.8771 Train-Acc:0.812
# I:287 Test-Acc:0.8772 Train-Acc:0.82
# I:288 Test-Acc:0.8767 Train-Acc:0.82
# I:289 Test-Acc:0.8769 Train-Acc:0.809
# I:290 Test-Acc:0.8779 Train-Acc:0.823
# I:291 Test-Acc:0.8788 Train-Acc:0.811
# I:292 Test-Acc:0.8771 Train-Acc:0.82
# I:293 Test-Acc:0.876 Train-Acc:0.812
# I:294 Test-Acc:0.8752 Train-Acc:0.817
# I:295 Test-Acc:0.8777 Train-Acc:0.821
# I:296 Test-Acc:0.8763 Train-Acc:0.816
# I:297 Test-Acc:0.8768 Train-Acc:0.814
# I:298 Test-Acc:0.8749 Train-Acc:0.805
# I:299 Test-Acc:0.8746 Train-Acc:0.818
